for fold in range(1, 6):
    print(f"\n{'='*60}")
    print(f"🚀 BẮT ĐẦU HUẤN LUYỆN YOLO26s-cls - FOLD {fold} ({CHOSEN_SCENARIO})")
    print(f"{'='*60}")

    fold_dir = os.path.join(K_FOLDS_DIR, f"Fold_{fold}")

    # ------------------------------------------
    # A. THỦ THUẬT ÉP YOLO ĐỌC ĐÚNG KỊCH BẢN
    # ------------------------------------------
    yolo_train_dir = os.path.join(fold_dir, "train")
    original_train_dir = os.path.join(fold_dir, "train_all_backup")
    scenario_dir = os.path.join(fold_dir, CHOSEN_SCENARIO)

    # Nếu đang có thư mục 'train' thật, đổi tên nó đi để tránh xóa nhầm
    if os.path.exists(yolo_train_dir) and not os.path.islink(yolo_train_dir):
        os.rename(yolo_train_dir, original_train_dir)

    # Tạo symlink (shortcut) tên 'train' trỏ vào thư mục Kịch Bản
    if os.path.islink(yolo_train_dir):
        os.unlink(yolo_train_dir)
    os.symlink(scenario_dir, yolo_train_dir)

    # ------------------------------------------
    # B. KHỞI TẠO MÔ HÌNH VÀ TRAIN
    # ------------------------------------------
    model = YOLO("yolo26s-cls.pt") # Khởi tạo lại weights mới tinh

    results = model.train(
        data=fold_dir,          # YOLO tự động tìm folder 'train' (symlink) và 'val'
        epochs=30,
        imgsz=128,
        batch=128,
        lr0=1e-4,
        patience=10,
        project="/content/drive/MyDrive/OMR-Datasets/train-cls-v2/scene2/Yolo26s",
        name=f"Fold_{fold}",
        # chỉnh TĂNG CƯỜNG ÁNH SÁNG (Photometric) CHO YOLO
        hsv_h=0.01,  # Chỉnh Tone màu nhẹ
        hsv_s=0.3,    # Chỉnh Saturation (Độ bão hòa)
        hsv_v=0.3,    # Chỉnh Sáng/Tối
    )

    # ------------------------------------------
    # C. ĐÁNH GIÁ NGAY TRÊN TẬP TEST (UNSEEN)
    # ------------------------------------------
    print(f"🔍 ĐÁNH GIÁ TẬP TEST FOLD {fold}")
    # YOLO đánh giá thư mục test
    test_results = model.val(data=fold_dir, split='test')

    # Lấy top1_acc từ kết quả
    top1_acc = test_results.top1
    print(f"✅ Accuracy Test Fold {fold}: {top1_acc:.4f}")
    fold_yolo_results.append(top1_acc)

# ==========================================
# 3. TỔNG KẾT BÀI BÁO (YOLO)
# ==========================================
print(f"\n🏆 KẾT QUẢ YOLO26s 5-FOLD ({CHOSEN_SCENARIO}):")
print(f"Danh sách Test Acc: {fold_yolo_results}")
print(f"ĐỘ CHÍNH XÁC TRUNG BÌNH: {np.mean(fold_yolo_results)*100:.2f}% ± {np.std(fold_yolo_results)*100:.2f}%")
# Out:
# ============================================================
# 🚀 BẮT ĐẦU HUẤN LUYỆN YOLO26s-cls - FOLD 1 (train_Scen2_withGAN)
# ============================================================
# Ultralytics 8.4.53 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=128, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/content/OMR_5Fold_ROIs_split/Fold_1, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.01, hsv_s=0.3, hsv_v=0.3, imgsz=128, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26s-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=Fold_1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/OMR-Datasets/train-cls-v2/scene2/Yolo26s, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /content/content/OMR_5Fold_ROIs_split/Fold_1/train... found 22589 images in 3 classes ✅
# val: /content/content/OMR_5Fold_ROIs_split/Fold_1/val... found 6933 images in 3 classes ✅
# test: /content/content/OMR_5Fold_ROIs_split/Fold_1/test... found 6405 images in 3 classes ✅
# Overriding model.yaml nc=1000 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  10                  -1  1    661763  ultralytics.nn.modules.head.Classify         [512, 3]
# YOLO26s-cls summary: 86 layers, 5,446,851 parameters, 5,446,851 gradients, 12.1 GFLOPs
# Transferred 234/236 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 91.0MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 196.8±74.4 MB/s, size: 3.6 KB)
# train: Scanning /content/content/OMR_5Fold_ROIs_split/Fold_1/train... 22589 images, 0 corrupt: 100% ━━━━━━━━━━━━ 22589/22589 5.9Kit/s 3.8s
# train: New cache created: /content/content/OMR_5Fold_ROIs_split/Fold_1/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 127.3±46.0 MB/s, size: 3.4 KB)
# val: Scanning /content/content/OMR_5Fold_ROIs_split/Fold_1/val... 6933 images, 0 corrupt: 100% ━━━━━━━━━━━━ 6933/6933 2.8Kit/s 2.5s
# val: New cache created: /content/content/OMR_5Fold_ROIs_split/Fold_1/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.0001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.001), 40 bias(decay=0.0)
# Image sizes 128 train, 128 val
# Using 2 dataloader workers
# Logging results to /content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_1
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 19.4MB/s 0.0s
#        1/30     0.949G     0.2694         61        128: 100% ━━━━━━━━━━━━ 177/177 3.2it/s 55.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 3.8it/s 7.4s
#                    all      0.992          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/30      1.17G    0.07802         61        128: 100% ━━━━━━━━━━━━ 177/177 3.3it/s 53.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 4.2it/s 6.6s
#                    all      0.993          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/30      1.17G    0.08297         61        128: 100% ━━━━━━━━━━━━ 177/177 3.1it/s 56.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 4.7it/s 6.0s
#                    all      0.989          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/30      1.17G    0.07166         61        128: 100% ━━━━━━━━━━━━ 177/177 3.2it/s 56.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 4.6it/s 6.1s
#                    all      0.988          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/30      1.17G    0.06166         61        128: 100% ━━━━━━━━━━━━ 177/177 3.2it/s 56.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 4.1it/s 6.9s
#                    all      0.992          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/30      1.17G    0.05809         61        128: 100% ━━━━━━━━━━━━ 177/177 3.2it/s 55.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 3.5it/s 8.0s
#                    all       0.99          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/30      1.17G    0.05142         61        128: 100% ━━━━━━━━━━━━ 177/177 3.1it/s 56.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 3.6it/s 7.7s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/30      1.17G    0.04356         61        128: 100% ━━━━━━━━━━━━ 177/177 3.0it/s 59.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 4.3it/s 6.5s
#                    all      0.989          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/30      1.17G    0.04065         61        128: 100% ━━━━━━━━━━━━ 177/177 3.1it/s 56.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 3.5it/s 8.0s
#                    all      0.991          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/30      1.17G    0.04115         61        128: 100% ━━━━━━━━━━━━ 177/177 3.2it/s 55.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all      0.992          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/30      1.17G    0.04021         61        128: 100% ━━━━━━━━━━━━ 177/177 3.1it/s 57.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 4.6it/s 6.1s
#                    all      0.992          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/30      1.17G     0.0354         61        128: 100% ━━━━━━━━━━━━ 177/177 3.1it/s 57.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 4.3it/s 6.5s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/30      1.17G    0.03397         61        128: 100% ━━━━━━━━━━━━ 177/177 3.0it/s 59.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 3.7it/s 7.7s
#                    all      0.993          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/30      1.17G    0.03333         61        128: 100% ━━━━━━━━━━━━ 177/177 3.2it/s 56.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 3.9it/s 7.3s
#                    all      0.995          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/30      1.17G    0.02969         61        128: 100% ━━━━━━━━━━━━ 177/177 3.1it/s 58.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 4.5it/s 6.2s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/30      1.17G    0.02939         61        128: 100% ━━━━━━━━━━━━ 177/177 3.1it/s 57.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 4.0it/s 7.1s
#                    all       0.99          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/30      1.17G      0.026         61        128: 100% ━━━━━━━━━━━━ 177/177 3.1it/s 57.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.2s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/30      1.17G    0.02372         61        128: 100% ━━━━━━━━━━━━ 177/177 3.2it/s 56.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 3.7it/s 7.6s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/30      1.17G    0.02265         61        128: 100% ━━━━━━━━━━━━ 177/177 3.1it/s 57.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 4.5it/s 6.2s
#                    all      0.995          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/30      1.17G    0.02008         61        128: 100% ━━━━━━━━━━━━ 177/177 3.0it/s 59.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.3s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/30      1.17G    0.02274         61        128: 100% ━━━━━━━━━━━━ 177/177 3.1it/s 57.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 3.7it/s 7.6s
#                    all      0.996          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/30      1.17G    0.01897         61        128: 100% ━━━━━━━━━━━━ 177/177 3.1it/s 57.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 4.8it/s 5.8s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/30      1.17G    0.01665         61        128: 100% ━━━━━━━━━━━━ 177/177 3.1it/s 57.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 3.9it/s 7.1s
#                    all      0.993          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/30      1.17G    0.01541         61        128: 100% ━━━━━━━━━━━━ 177/177 3.2it/s 54.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 3.4it/s 8.3s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/30      1.17G    0.01426         61        128: 100% ━━━━━━━━━━━━ 177/177 3.3it/s 53.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 3.5it/s 8.0s
#                    all      0.992          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       26/30      1.17G    0.01136         61        128: 100% ━━━━━━━━━━━━ 177/177 3.2it/s 54.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 3.7it/s 7.5s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       27/30      1.17G    0.01321         61        128: 100% ━━━━━━━━━━━━ 177/177 3.2it/s 55.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 4.4it/s 6.4s
#                    all      0.993          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       28/30      1.17G     0.0107         61        128: 100% ━━━━━━━━━━━━ 177/177 3.2it/s 56.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 4.3it/s 6.5s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       29/30      1.17G   0.009422         61        128: 100% ━━━━━━━━━━━━ 177/177 3.2it/s 56.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 3.3it/s 8.5s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       30/30      1.17G   0.009803         61        128: 100% ━━━━━━━━━━━━ 177/177 3.2it/s 55.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 3.3it/s 8.5s
#                    all      0.994          1
#
# 30 epochs completed in 0.539 hours.
# Optimizer stripped from /content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_1/weights/last.pt, 11.0MB
# Optimizer stripped from /content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_1/weights/best.pt, 11.0MB
#
# Validating /content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_1/weights/best.pt...
# Ultralytics 8.4.53 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26s-cls summary (fused): 47 layers, 5,437,971 parameters, 0 gradients, 12.0 GFLOPs
# train: /content/content/OMR_5Fold_ROIs_split/Fold_1/train... found 22589 images in 3 classes ✅
# val: /content/content/OMR_5Fold_ROIs_split/Fold_1/val... found 6933 images in 3 classes ✅
# test: /content/content/OMR_5Fold_ROIs_split/Fold_1/test... found 6405 images in 3 classes ✅
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 28/28 5.6it/s 5.0s
#                    all      0.996          1
# Speed: 0.0ms preprocess, 0.2ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_1
# 🔍 ĐÁNH GIÁ TẬP TEST FOLD 1
# Ultralytics 8.4.53 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26s-cls summary (fused): 47 layers, 5,437,971 parameters, 0 gradients, 12.0 GFLOPs
# train: /content/content/OMR_5Fold_ROIs_split/Fold_1/train... found 22589 images in 3 classes ✅
# val: /content/content/OMR_5Fold_ROIs_split/Fold_1/val... found 6933 images in 3 classes ✅
# test: /content/content/OMR_5Fold_ROIs_split/Fold_1/test... found 6405 images in 3 classes ✅
# test: Fast image access ✅ (ping: 0.0±0.0 ms, read: 174.7±74.0 MB/s, size: 3.3 KB)
# test: Scanning /content/content/OMR_5Fold_ROIs_split/Fold_1/test... 6405 images, 0 corrupt: 100% ━━━━━━━━━━━━ 6405/6405 5.2Kit/s 1.2s
# test: New cache created: /content/content/OMR_5Fold_ROIs_split/Fold_1/test.cache
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 401/401 44.5it/s 9.0s
#                    all      0.992          1
# Speed: 0.0ms preprocess, 1.0ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /content/runs/classify/val
# ✅ Accuracy Test Fold 1: 0.9919
#
# ============================================================
# 🚀 BẮT ĐẦU HUẤN LUYỆN YOLO26s-cls - FOLD 2 (train_Scen2_withGAN)
# ============================================================
# Ultralytics 8.4.53 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=128, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/content/OMR_5Fold_ROIs_split/Fold_2, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.01, hsv_s=0.3, hsv_v=0.3, imgsz=128, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26s-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=Fold_2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/OMR-Datasets/train-cls-v2/scene2/Yolo26s, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /content/content/OMR_5Fold_ROIs_split/Fold_2/train... found 22416 images in 3 classes ✅
# val: /content/content/OMR_5Fold_ROIs_split/Fold_2/val... found 6900 images in 3 classes ✅
# test: /content/content/OMR_5Fold_ROIs_split/Fold_2/test... found 6615 images in 3 classes ✅
# Overriding model.yaml nc=1000 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  10                  -1  1    661763  ultralytics.nn.modules.head.Classify         [512, 3]
# YOLO26s-cls summary: 86 layers, 5,446,851 parameters, 5,446,851 gradients, 12.1 GFLOPs
# Transferred 234/236 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4.0±3.1 MB/s, size: 3.6 KB)
# train: Scanning /content/content/OMR_5Fold_ROIs_split/Fold_2/train... 22416 images, 0 corrupt: 100% ━━━━━━━━━━━━ 22416/22416 2.0Kit/s 11.2s
# train: New cache created: /content/content/OMR_5Fold_ROIs_split/Fold_2/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4.7±2.3 MB/s, size: 3.4 KB)
# val: Scanning /content/content/OMR_5Fold_ROIs_split/Fold_2/val... 6900 images, 0 corrupt: 100% ━━━━━━━━━━━━ 6900/6900 1.2Kit/s 5.6s
# val: New cache created: /content/content/OMR_5Fold_ROIs_split/Fold_2/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.0001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.001), 40 bias(decay=0.0)
# Image sizes 128 train, 128 val
# Using 2 dataloader workers
# Logging results to /content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_2
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/30      1.05G     0.2738         16        128: 100% ━━━━━━━━━━━━ 176/176 3.0it/s 59.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.4it/s 6.1s
#                    all      0.991          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/30      1.27G    0.07344         16        128: 100% ━━━━━━━━━━━━ 176/176 3.1it/s 56.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.6it/s 5.9s
#                    all      0.988          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/30      1.27G    0.08678         16        128: 100% ━━━━━━━━━━━━ 176/176 3.1it/s 57.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.3it/s 6.3s
#                    all      0.988          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/30      1.27G    0.07547         16        128: 100% ━━━━━━━━━━━━ 176/176 3.1it/s 56.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.3it/s 8.1s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/30      1.27G    0.06267         16        128: 100% ━━━━━━━━━━━━ 176/176 3.2it/s 54.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.5it/s 7.7s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/30      1.27G    0.05872         16        128: 100% ━━━━━━━━━━━━ 176/176 3.2it/s 55.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.0it/s 6.8s
#                    all      0.988          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/30      1.27G    0.06129         16        128: 100% ━━━━━━━━━━━━ 176/176 3.2it/s 54.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.0it/s 6.7s
#                    all       0.99          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/30      1.27G    0.04916         16        128: 100% ━━━━━━━━━━━━ 176/176 3.2it/s 55.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.4it/s 6.1s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/30      1.27G     0.0481         16        128: 100% ━━━━━━━━━━━━ 176/176 3.2it/s 55.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.7it/s 5.7s
#                    all      0.995          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/30      1.27G    0.04552         16        128: 100% ━━━━━━━━━━━━ 176/176 3.1it/s 56.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.5it/s 6.0s
#                    all      0.991          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/30      1.27G    0.04946         16        128: 100% ━━━━━━━━━━━━ 176/176 3.2it/s 55.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.6it/s 5.9s
#                    all      0.993          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/30      1.27G     0.0463         16        128: 100% ━━━━━━━━━━━━ 176/176 3.2it/s 55.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.9it/s 6.9s
#                    all      0.993          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/30      1.27G    0.03741         16        128: 100% ━━━━━━━━━━━━ 176/176 3.2it/s 54.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.3it/s 8.1s
#                    all      0.995          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/30      1.27G    0.03902         16        128: 100% ━━━━━━━━━━━━ 176/176 3.2it/s 54.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.4it/s 8.0s
#                    all      0.995          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/30      1.27G    0.02865         16        128: 100% ━━━━━━━━━━━━ 176/176 3.1it/s 56.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.2s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/30      1.27G    0.03342         16        128: 100% ━━━━━━━━━━━━ 176/176 3.1it/s 56.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.1it/s 6.6s
#                    all      0.993          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/30      1.27G    0.02404         16        128: 100% ━━━━━━━━━━━━ 176/176 3.2it/s 55.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.8it/s 5.6s
#                    all      0.996          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/30      1.27G     0.0282         16        128: 100% ━━━━━━━━━━━━ 176/176 3.1it/s 56.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.8it/s 5.6s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/30      1.27G    0.02342         16        128: 100% ━━━━━━━━━━━━ 176/176 3.2it/s 54.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.3it/s 6.3s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/30      1.27G    0.02125         16        128: 100% ━━━━━━━━━━━━ 176/176 3.3it/s 54.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.3it/s 6.3s
#                    all      0.996          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/30      1.27G     0.0206         16        128: 100% ━━━━━━━━━━━━ 176/176 3.2it/s 55.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.3it/s 8.1s
#                    all      0.996          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/30      1.27G    0.02413         16        128: 100% ━━━━━━━━━━━━ 176/176 3.3it/s 53.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.3it/s 8.1s
#                    all      0.996          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/30      1.27G    0.01979         16        128: 100% ━━━━━━━━━━━━ 176/176 3.3it/s 53.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.4it/s 7.9s
#                    all      0.995          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/30      1.27G    0.01485         16        128: 100% ━━━━━━━━━━━━ 176/176 3.4it/s 52.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.4it/s 8.0s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/30      1.27G    0.01742         16        128: 100% ━━━━━━━━━━━━ 176/176 3.4it/s 51.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.5it/s 7.8s
#                    all      0.995          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       26/30      1.27G    0.01348         16        128: 100% ━━━━━━━━━━━━ 176/176 3.4it/s 52.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.4it/s 8.0s
#                    all      0.995          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       27/30      1.27G    0.01179         16        128: 100% ━━━━━━━━━━━━ 176/176 3.4it/s 51.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.4it/s 7.9s
#                    all      0.995          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       28/30      1.27G    0.01403         16        128: 100% ━━━━━━━━━━━━ 176/176 3.3it/s 52.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.4it/s 7.8s
#                    all      0.995          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       29/30      1.27G   0.009649         16        128: 100% ━━━━━━━━━━━━ 176/176 3.4it/s 51.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.3it/s 8.1s
#                    all      0.995          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       30/30      1.27G    0.01087         16        128: 100% ━━━━━━━━━━━━ 176/176 3.3it/s 52.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.3it/s 8.2s
#                    all      0.995          1
#
# 30 epochs completed in 0.523 hours.
# Optimizer stripped from /content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_2/weights/last.pt, 11.0MB
# Optimizer stripped from /content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_2/weights/best.pt, 11.0MB
#
# Validating /content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_2/weights/best.pt...
# Ultralytics 8.4.53 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26s-cls summary (fused): 47 layers, 5,437,971 parameters, 0 gradients, 12.0 GFLOPs
# train: /content/content/OMR_5Fold_ROIs_split/Fold_2/train... found 22416 images in 3 classes ✅
# val: /content/content/OMR_5Fold_ROIs_split/Fold_2/val... found 6900 images in 3 classes ✅
# test: /content/content/OMR_5Fold_ROIs_split/Fold_2/test... found 6615 images in 3 classes ✅
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.8it/s 5.6s
#                    all      0.996          1
# Speed: 0.0ms preprocess, 0.2ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_2
# 🔍 ĐÁNH GIÁ TẬP TEST FOLD 2
# Ultralytics 8.4.53 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26s-cls summary (fused): 47 layers, 5,437,971 parameters, 0 gradients, 12.0 GFLOPs
# train: /content/content/OMR_5Fold_ROIs_split/Fold_2/train... found 22416 images in 3 classes ✅
# val: /content/content/OMR_5Fold_ROIs_split/Fold_2/val... found 6900 images in 3 classes ✅
# test: /content/content/OMR_5Fold_ROIs_split/Fold_2/test... found 6615 images in 3 classes ✅
# test: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4.8±2.5 MB/s, size: 3.0 KB)
# test: Scanning /content/content/OMR_5Fold_ROIs_split/Fold_2/test... 6615 images, 0 corrupt: 100% ━━━━━━━━━━━━ 6615/6615 2.2Kit/s 2.9s
# test: New cache created: /content/content/OMR_5Fold_ROIs_split/Fold_2/test.cache
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 414/414 40.6it/s 10.2s
#                    all      0.996          1
# Speed: 0.0ms preprocess, 1.0ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /content/runs/classify/val-2
# ✅ Accuracy Test Fold 2: 0.9962
#
# ============================================================
# 🚀 BẮT ĐẦU HUẤN LUYỆN YOLO26s-cls - FOLD 3 (train_Scen2_withGAN)
# ============================================================
# Ultralytics 8.4.53 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=128, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/content/OMR_5Fold_ROIs_split/Fold_3, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.01, hsv_s=0.3, hsv_v=0.3, imgsz=128, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26s-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=Fold_3, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/OMR-Datasets/train-cls-v2/scene2/Yolo26s, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_3, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /content/content/OMR_5Fold_ROIs_split/Fold_3/train... found 22422 images in 3 classes ✅
# val: /content/content/OMR_5Fold_ROIs_split/Fold_3/val... found 6870 images in 3 classes ✅
# test: /content/content/OMR_5Fold_ROIs_split/Fold_3/test... found 6636 images in 3 classes ✅
# Overriding model.yaml nc=1000 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  10                  -1  1    661763  ultralytics.nn.modules.head.Classify         [512, 3]
# YOLO26s-cls summary: 86 layers, 5,446,851 parameters, 5,446,851 gradients, 12.1 GFLOPs
# Transferred 234/236 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 4.5±2.4 MB/s, size: 3.4 KB)
# train: Scanning /content/content/OMR_5Fold_ROIs_split/Fold_3/train... 22422 images, 0 corrupt: 100% ━━━━━━━━━━━━ 22422/22422 2.1Kit/s 10.6s
# train: New cache created: /content/content/OMR_5Fold_ROIs_split/Fold_3/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5.4±0.9 MB/s, size: 3.3 KB)
# val: Scanning /content/content/OMR_5Fold_ROIs_split/Fold_3/val... 6870 images, 0 corrupt: 100% ━━━━━━━━━━━━ 6870/6870 1.5Kit/s 4.4s
# val: New cache created: /content/content/OMR_5Fold_ROIs_split/Fold_3/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.0001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.001), 40 bias(decay=0.0)
# Image sizes 128 train, 128 val
# Using 2 dataloader workers
# Logging results to /content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_3
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/30      1.05G     0.2657         22        128: 100% ━━━━━━━━━━━━ 176/176 3.0it/s 58.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.5it/s 5.9s
#                    all      0.712          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/30      1.27G    0.08148         22        128: 100% ━━━━━━━━━━━━ 176/176 3.1it/s 56.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.5it/s 6.0s
#                    all      0.985          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/30      1.27G    0.08773         22        128: 100% ━━━━━━━━━━━━ 176/176 3.1it/s 57.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.3it/s 8.2s
#                    all      0.987          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/30      1.27G    0.07348         22        128: 100% ━━━━━━━━━━━━ 176/176 3.1it/s 56.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.4it/s 8.0s
#                    all       0.99          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/30      1.27G      0.061         22        128: 100% ━━━━━━━━━━━━ 176/176 3.0it/s 58.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.3it/s 6.3s
#                    all      0.991          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/30      1.27G    0.05216         22        128: 100% ━━━━━━━━━━━━ 176/176 3.0it/s 59.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.5it/s 7.7s
#                    all      0.981          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/30      1.27G    0.05292         22        128: 100% ━━━━━━━━━━━━ 176/176 3.2it/s 55.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.2it/s 8.4s
#                    all      0.988          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/30      1.27G    0.04429         22        128: 100% ━━━━━━━━━━━━ 176/176 3.1it/s 56.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.0it/s 6.7s
#                    all      0.993          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/30      1.27G    0.05066         22        128: 100% ━━━━━━━━━━━━ 176/176 3.0it/s 59.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.2it/s 6.4s
#                    all      0.992          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/30      1.27G    0.04478         22        128: 100% ━━━━━━━━━━━━ 176/176 3.1it/s 57.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.3it/s 8.1s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/30      1.27G    0.04326         22        128: 100% ━━━━━━━━━━━━ 176/176 3.0it/s 57.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.4it/s 7.9s
#                    all      0.993          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/30      1.27G    0.03687         22        128: 100% ━━━━━━━━━━━━ 176/176 3.0it/s 57.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.4it/s 6.1s
#                    all      0.993          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/30      1.27G    0.03572         22        128: 100% ━━━━━━━━━━━━ 176/176 3.1it/s 57.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.3it/s 6.3s
#                    all      0.993          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/30      1.27G    0.03455         22        128: 100% ━━━━━━━━━━━━ 176/176 3.2it/s 55.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.1s
#                    all      0.995          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/30      1.27G    0.03321         22        128: 100% ━━━━━━━━━━━━ 176/176 3.1it/s 56.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.2it/s 8.5s
#                    all      0.992          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/30      1.27G    0.02869         22        128: 100% ━━━━━━━━━━━━ 176/176 3.2it/s 55.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.5it/s 7.8s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/30      1.27G     0.0262         22        128: 100% ━━━━━━━━━━━━ 176/176 3.1it/s 57.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.4it/s 6.1s
#                    all      0.993          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/30      1.27G    0.02507         22        128: 100% ━━━━━━━━━━━━ 176/176 3.1it/s 56.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.4it/s 6.2s
#                    all      0.995          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/30      1.27G    0.02242         22        128: 100% ━━━━━━━━━━━━ 176/176 3.0it/s 57.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.5it/s 7.8s
#                    all      0.992          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/30      1.27G    0.02131         22        128: 100% ━━━━━━━━━━━━ 176/176 3.2it/s 55.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.3it/s 8.1s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/30      1.27G    0.02172         22        128: 100% ━━━━━━━━━━━━ 176/176 3.0it/s 58.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.2it/s 6.4s
#                    all      0.993          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/30      1.27G     0.0214         22        128: 100% ━━━━━━━━━━━━ 176/176 3.1it/s 57.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.4it/s 6.1s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/30      1.27G    0.01919         22        128: 100% ━━━━━━━━━━━━ 176/176 3.2it/s 55.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.5it/s 6.0s
#                    all      0.995          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/30      1.27G    0.01506         22        128: 100% ━━━━━━━━━━━━ 176/176 3.2it/s 55.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.3it/s 8.2s
#                    all      0.995          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/30      1.27G    0.01873         22        128: 100% ━━━━━━━━━━━━ 176/176 3.2it/s 54.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.3it/s 8.3s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       26/30      1.27G    0.01654         22        128: 100% ━━━━━━━━━━━━ 176/176 3.2it/s 54.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.4it/s 7.9s
#                    all      0.995          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       27/30      1.27G    0.01494         22        128: 100% ━━━━━━━━━━━━ 176/176 3.2it/s 55.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.8it/s 7.2s
#                    all      0.996          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       28/30      1.27G    0.01184         22        128: 100% ━━━━━━━━━━━━ 176/176 3.0it/s 57.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.2it/s 6.4s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       29/30      1.27G    0.01254         22        128: 100% ━━━━━━━━━━━━ 176/176 3.1it/s 56.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.3it/s 6.2s
#                    all      0.995          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       30/30      1.27G    0.01058         22        128: 100% ━━━━━━━━━━━━ 176/176 3.1it/s 57.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.2it/s 6.4s
#                    all      0.995          1
#
# 30 epochs completed in 0.542 hours.
# Optimizer stripped from /content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_3/weights/last.pt, 11.0MB
# Optimizer stripped from /content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_3/weights/best.pt, 11.0MB
#
# Validating /content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_3/weights/best.pt...
# Ultralytics 8.4.53 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26s-cls summary (fused): 47 layers, 5,437,971 parameters, 0 gradients, 12.0 GFLOPs
# train: /content/content/OMR_5Fold_ROIs_split/Fold_3/train... found 22422 images in 3 classes ✅
# val: /content/content/OMR_5Fold_ROIs_split/Fold_3/val... found 6870 images in 3 classes ✅
# test: /content/content/OMR_5Fold_ROIs_split/Fold_3/test... found 6636 images in 3 classes ✅
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 5.0it/s 5.4s
#                    all      0.996          1
# Speed: 0.0ms preprocess, 0.2ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_3
# 🔍 ĐÁNH GIÁ TẬP TEST FOLD 3
# Ultralytics 8.4.53 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26s-cls summary (fused): 47 layers, 5,437,971 parameters, 0 gradients, 12.0 GFLOPs
# train: /content/content/OMR_5Fold_ROIs_split/Fold_3/train... found 22422 images in 3 classes ✅
# val: /content/content/OMR_5Fold_ROIs_split/Fold_3/val... found 6870 images in 3 classes ✅
# test: /content/content/OMR_5Fold_ROIs_split/Fold_3/test... found 6636 images in 3 classes ✅
# test: Fast image access ✅ (ping: 0.0±0.0 ms, read: 6.8±2.0 MB/s, size: 3.6 KB)
# test: Scanning /content/content/OMR_5Fold_ROIs_split/Fold_3/test... 6636 images, 0 corrupt: 100% ━━━━━━━━━━━━ 6636/6636 2.1Kit/s 3.2s
# test: New cache created: /content/content/OMR_5Fold_ROIs_split/Fold_3/test.cache
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 415/415 50.4it/s 8.2s
#                    all      0.995          1
# Speed: 0.0ms preprocess, 0.9ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /content/runs/classify/val-3
# ✅ Accuracy Test Fold 3: 0.9946
#
# ...
# YOLO26s-cls summary (fused): 47 layers, 5,437,971 parameters, 0 gradients, 12.0 GFLOPs
# train: /content/content/OMR_5Fold_ROIs_split/Fold_4/train... found 22390 images in 3 classes ✅
# val: /content/content/OMR_5Fold_ROIs_split/Fold_4/val... found 6822 images in 3 classes ✅
# test: /content/content/OMR_5Fold_ROIs_split/Fold_4/test... found 6717 images in 3 classes ✅
# test: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3.6±2.5 MB/s, size: 3.2 KB)
# test: Scanning /content/content/OMR_5Fold_ROIs_split/Fold_4/test... 6717 images, 0 corrupt: 100% ━━━━━━━━━━━━ 6717/6717 2.0Kit/s 3.3s
# test: New cache created: /content/content/OMR_5Fold_ROIs_split/Fold_4/test.cache
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 420/420 47.2it/s 8.9s
#                    all      0.995          1
# Speed: 0.0ms preprocess, 1.0ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /content/runs/classify/val-4
# ✅ Accuracy Test Fold 4: 0.9946
#
# ============================================================
# 🚀 BẮT ĐẦU HUẤN LUYỆN YOLO26s-cls - FOLD 5 (train_Scen2_withGAN)
# ============================================================
# Ultralytics 8.4.53 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=128, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/content/OMR_5Fold_ROIs_split/Fold_5, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=30, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.01, hsv_s=0.3, hsv_v=0.3, imgsz=128, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26s-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=Fold_5, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/OMR-Datasets/train-cls-v2/scene2/Yolo26s, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_5, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /content/content/OMR_5Fold_ROIs_split/Fold_5/train... found 22008 images in 3 classes ✅
# val: /content/content/OMR_5Fold_ROIs_split/Fold_5/val... found 6750 images in 3 classes ✅
# test: /content/content/OMR_5Fold_ROIs_split/Fold_5/test... found 7176 images in 3 classes ✅
# Overriding model.yaml nc=1000 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  10                  -1  1    661763  ultralytics.nn.modules.head.Classify         [512, 3]
# YOLO26s-cls summary: 86 layers, 5,446,851 parameters, 5,446,851 gradients, 12.1 GFLOPs
# Transferred 234/236 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 6.1±1.7 MB/s, size: 3.6 KB)
# train: Scanning /content/content/OMR_5Fold_ROIs_split/Fold_5/train... 22008 images, 0 corrupt: 100% ━━━━━━━━━━━━ 22008/22008 2.1Kit/s 10.6s
# train: New cache created: /content/content/OMR_5Fold_ROIs_split/Fold_5/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2.1±1.5 MB/s, size: 3.3 KB)
# val: Scanning /content/content/OMR_5Fold_ROIs_split/Fold_5/val... 6750 images, 0 corrupt: 100% ━━━━━━━━━━━━ 6750/6750 1.2Kit/s 5.6s
# val: New cache created: /content/content/OMR_5Fold_ROIs_split/Fold_5/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.0001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 39 weight(decay=0.0), 40 weight(decay=0.001), 40 bias(decay=0.0)
# Image sizes 128 train, 128 val
# Using 2 dataloader workers
# Logging results to /content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_5
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/30      1.05G     0.2766        120        128: 100% ━━━━━━━━━━━━ 172/172 3.1it/s 55.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.6it/s 7.6s
#                    all      0.991          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/30      1.27G    0.08185        120        128: 100% ━━━━━━━━━━━━ 172/172 3.2it/s 53.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.4it/s 8.0s
#                    all      0.992          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/30      1.27G    0.09093        120        128: 100% ━━━━━━━━━━━━ 172/172 3.0it/s 57.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.4it/s 6.1s
#                    all      0.988          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/30      1.27G    0.08487        120        128: 100% ━━━━━━━━━━━━ 172/172 3.1it/s 55.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.2it/s 6.4s
#                    all      0.991          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/30      1.27G    0.07037        120        128: 100% ━━━━━━━━━━━━ 172/172 3.0it/s 56.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.3it/s 6.3s
#                    all      0.992          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/30      1.27G    0.05974        120        128: 100% ━━━━━━━━━━━━ 172/172 3.0it/s 56.7s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.6it/s 7.5s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/30      1.27G    0.04987        120        128: 100% ━━━━━━━━━━━━ 172/172 3.0it/s 56.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.1it/s 8.6s
#                    all      0.989          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/30      1.27G    0.04864        120        128: 100% ━━━━━━━━━━━━ 172/172 3.0it/s 58.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.6it/s 7.5s
#                    all      0.993          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/30      1.27G    0.04413        120        128: 100% ━━━━━━━━━━━━ 172/172 3.0it/s 57.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.2it/s 6.4s
#                    all      0.989          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/30      1.27G    0.03715        120        128: 100% ━━━━━━━━━━━━ 172/172 3.1it/s 56.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.2it/s 6.4s
#                    all      0.993          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/30      1.27G    0.03751        120        128: 100% ━━━━━━━━━━━━ 172/172 3.1it/s 55.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.3it/s 6.3s
#                    all      0.993          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/30      1.27G    0.03712        120        128: 100% ━━━━━━━━━━━━ 172/172 3.1it/s 55.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.3it/s 6.3s
#                    all      0.993          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/30      1.27G    0.03253        120        128: 100% ━━━━━━━━━━━━ 172/172 3.1it/s 55.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.3it/s 6.2s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/30      1.27G    0.03222        120        128: 100% ━━━━━━━━━━━━ 172/172 3.1it/s 55.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.0it/s 6.8s
#                    all      0.992          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/30      1.27G    0.03592        120        128: 100% ━━━━━━━━━━━━ 172/172 3.1it/s 56.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.3it/s 6.3s
#                    all      0.995          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       16/30      1.27G    0.02736        120        128: 100% ━━━━━━━━━━━━ 172/172 3.0it/s 57.5s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.2it/s 8.4s
#                    all      0.995          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       17/30      1.27G    0.02755        120        128: 100% ━━━━━━━━━━━━ 172/172 3.1it/s 56.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 2.9it/s 9.2s
#                    all      0.993          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       18/30      1.27G    0.02477        120        128: 100% ━━━━━━━━━━━━ 172/172 3.0it/s 58.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.1it/s 6.6s
#                    all      0.995          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       19/30      1.27G    0.02369        120        128: 100% ━━━━━━━━━━━━ 172/172 3.0it/s 57.9s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.1it/s 6.5s
#                    all      0.993          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       20/30      1.27G    0.02204        120        128: 100% ━━━━━━━━━━━━ 172/172 3.0it/s 57.4s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.0it/s 6.7s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       21/30      1.27G    0.02271        120        128: 100% ━━━━━━━━━━━━ 172/172 2.9it/s 58.8s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.2it/s 8.5s
#                    all      0.994          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       22/30      1.27G     0.0183        120        128: 100% ━━━━━━━━━━━━ 172/172 3.1it/s 56.3s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.7it/s 7.2s
#                    all      0.993          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       23/30      1.27G    0.01751        120        128: 100% ━━━━━━━━━━━━ 172/172 3.0it/s 57.6s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.3it/s 6.3s
#                    all      0.995          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       24/30      1.27G    0.01344        120        128: 100% ━━━━━━━━━━━━ 172/172 3.0it/s 57.2s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.2it/s 6.4s
#                    all      0.991          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       25/30      1.27G    0.01546        120        128: 100% ━━━━━━━━━━━━ 172/172 3.0it/s 58.1s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 3.9it/s 6.8s
#                    all      0.994          1
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 15, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 25 epochs completed in 0.450 hours.
# Optimizer stripped from /content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_5/weights/last.pt, 11.0MB
# Optimizer stripped from /content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_5/weights/best.pt, 11.0MB
#
# Validating /content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_5/weights/best.pt...
# Ultralytics 8.4.53 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26s-cls summary (fused): 47 layers, 5,437,971 parameters, 0 gradients, 12.0 GFLOPs
# train: /content/content/OMR_5Fold_ROIs_split/Fold_5/train... found 22008 images in 3 classes ✅
# val: /content/content/OMR_5Fold_ROIs_split/Fold_5/val... found 6750 images in 3 classes ✅
# test: /content/content/OMR_5Fold_ROIs_split/Fold_5/test... found 7176 images in 3 classes ✅
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 27/27 4.9it/s 5.5s
#                    all      0.995          1
# Speed: 0.0ms preprocess, 0.2ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /content/drive/.shortcut-targets-by-id/1vKB6uCjVFhwlp6gA2Lk7NUI2OWmxBOc7/OMR-Datasets/train-cls-v2/scene2/Yolo26s/Fold_5
# 🔍 ĐÁNH GIÁ TẬP TEST FOLD 5
# Ultralytics 8.4.53 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO26s-cls summary (fused): 47 layers, 5,437,971 parameters, 0 gradients, 12.0 GFLOPs
# train: /content/content/OMR_5Fold_ROIs_split/Fold_5/train... found 22008 images in 3 classes ✅
# val: /content/content/OMR_5Fold_ROIs_split/Fold_5/val... found 6750 images in 3 classes ✅
# test: /content/content/OMR_5Fold_ROIs_split/Fold_5/test... found 7176 images in 3 classes ✅
# test: Fast image access ✅ (ping: 0.0±0.0 ms, read: 6.2±3.0 MB/s, size: 3.4 KB)
# test: Scanning /content/content/OMR_5Fold_ROIs_split/Fold_5/test... 7176 images, 0 corrupt: 100% ━━━━━━━━━━━━ 7176/7176 2.1Kit/s 3.5s
# test: New cache created: /content/content/OMR_5Fold_ROIs_split/Fold_5/test.cache
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 449/449 44.0it/s 10.2s
#                    all      0.997          1
# Speed: 0.0ms preprocess, 1.0ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /content/runs/classify/val-5
# ✅ Accuracy Test Fold 5: 0.9965
#
# 🏆 KẾT QUẢ YOLO26s 5-FOLD (train_Scen2_withGAN):
# Danh sách Test Acc: [0.9918813705444336, 0.9962207078933716, 0.994575023651123, 0.9946404695510864, 0.9965161681175232]
# ĐỘ CHÍNH XÁC TRUNG BÌNH: 99.48% ± 0.16%
